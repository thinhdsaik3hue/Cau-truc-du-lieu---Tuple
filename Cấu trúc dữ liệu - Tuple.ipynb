# %%
t = (12, 45, -1, -0.56, "abc", True)
print(t)
print('t[-1]: ', t[-1])
print('t[0]: ', t[0])
print('t[1:4]: ', t[1:4])
print('t[2:5]: ', t[2:5])
list(t)
# Out:
# (12, 45, -1, -0.56, 'abc', True)
# t[-1]:  True
# t[0]:  12
# t[1:4]:  (45, -1, -0.56)
# t[2:5]:  (-1, -0.56, 'abc')
# [12, 45, -1, -0.56, 'abc', True]
